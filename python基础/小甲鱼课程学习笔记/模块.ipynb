# %% [markdown]
# # 模块的导入

# %%
from magic_method import Temperature as TP

tp=TP()
tp.cel=39.1
tp.fah=200
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\wangkai\Desktop\pythonwork\小甲鱼课程学习笔记\模块.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/wangkai/Desktop/pythonwork/%E5%B0%8F%E7%94%B2%E9%B1%BC%E8%AF%BE%E7%A8%8B%E5%AD%A6%E4%B9%A0%E7%AC%94%E8%AE%B0/%E6%A8%A1%E5%9D%97.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from magic_method import Temperature as TP
#       <a href='vscode-notebook-cell:/c%3A/Users/wangkai/Desktop/pythonwork/%E5%B0%8F%E7%94%B2%E9%B1%BC%E8%AF%BE%E7%A8%8B%E5%AD%A6%E4%B9%A0%E7%AC%94%E8%AE%B0/%E6%A8%A1%E5%9D%97.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> tp=TP()
#       <a href='vscode-notebook-cell:/c%3A/Users/wangkai/Desktop/pythonwork/%E5%B0%8F%E7%94%B2%E9%B1%BC%E8%AF%BE%E7%A8%8B%E5%AD%A6%E4%B9%A0%E7%AC%94%E8%AE%B0/%E6%A8%A1%E5%9D%97.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> tp.cel=39.1
#
# ...

# %% [markdown]
# if __name__=="__main__"这句代码可以避免模块的测试程序在作为模块调用进去的时候输出结果
#
# 搜索路径：

# %% [markdown]
# ### sys的编译路径

# %%
import sys
print(sys.path)
sys.path.append(r"C:\Users\wangkai\Desktop")#换成绝对路径
print(sys.path)
# Out:
# ['c:\\Users\\wangkai\\Desktop\\pythonwork\\小甲鱼课程学习笔记', 'd:\\soft\\python\\python310.zip', 'd:\\soft\\python\\DLLs', 'd:\\soft\\python\\lib', 'd:\\soft\\python', '', 'C:\\Users\\wangkai\\AppData\\Roaming\\Python\\Python310\\site-packages', 'd:\\soft\\python\\lib\\site-packages', 'd:\\soft\\python\\lib\\site-packages\\chardet-3.0.4-py3.10.egg', 'd:\\deeplearning\\pointnet', 'd:\\soft\\python\\lib\\site-packages\\win32', 'd:\\soft\\python\\lib\\site-packages\\win32\\lib', 'd:\\soft\\python\\lib\\site-packages\\Pythonwin']
# ...

# %% [markdown]
# 包package,包就是一个文件，***但是文件夹必须有一个__init__.py的文件***
# 导入的时候是 import package.Temperature as TP
#
# python的电池：python的标准库
#
# https://pypi.python.org/pypi  社区

# %%
import timeit 
print(timeit.__doc__)
dir(timeit)
timeit.__all__#可调用的所有属性
#from timeit import *#只会导入__all__这个列表中的属性和方法和类
timeit.__file__#源代码所在的位置
help(timeit)
dir(timeit)
# Out:
# Tool for measuring execution time of small code snippets.
#
# This module avoids a number of common traps for measuring execution
# times.  See also Tim Peters' introduction to the Algorithms chapter in
# the Python Cookbook, published by O'Reilly.
#
# Library usage: see the Timer class.
#
# Command line usage:
#     python timeit.py [-n N] [-r N] [-s S] [-p] [-h] [--] [statement]
#
# Options:
#   -n/--number N: how many times to execute 'statement' (default: see below)
#   -r/--repeat N: how many times to repeat the timer (default 5)
#   -s/--setup S: statement to be executed once initially (default 'pass').
#                 Execution time of this setup statement is NOT timed.
#   -p/--process: use time.process_time() (default is time.perf_counter())
#   -v/--verbose: print raw timing results; repeat for more digits precision
#   -u/--unit: set the output time unit (nsec, usec, msec, or sec)
#   -h/--help: print this usage message and exit
# ...

# %% [markdown]
# from 文件夹 import 文件

# %%
import sys
import os
sys.path.append(os.path.abspath('D:\deeplearning\pseudo_lidar-master\psmnet'))
from models import *
model = stackhourglass(192)
print(model)
# Out:
# PSMNet(
#   (feature_extraction): feature_extraction(
#     (firstconv): Sequential(
#       (0): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): ReLU(inplace=True)
#       (2): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): ReLU(inplace=True)
#       (4): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): ReLU(inplace=True)
#     )
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Sequential(
#           (0): Sequential(
# ...
